# %% [markdown]
# <a href="https://colab.research.google.com/github/barakath-haseena/sales-data-analysis/blob/main/analysis_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

sales_summary = df.groupby("Product")["Revenue"].sum().reset_index()
print("Total Revenue per Product:")
print(sales_summary)

daily_sales = df.groupby("Date")["Revenue"].sum().reset_index()
print("\nTotal Revenue per Day:")
print(daily_sales)

plt.figure(figsize=(8, 5))
plt.bar(sales_summary["Product"], sales_summary["Revenue"], color="skyblue")
plt.xticks(rotation=45, ha="right")
plt.title("Total Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue ($)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(daily_sales["Date"], daily_sales["Revenue"], marker="o", color="green")
plt.title("Daily Revenue Trend")
plt.xlabel("Date")
plt.ylabel("Revenue ($)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Total Revenue per Product:
#                    Product  Revenue
# 0      Chanel No.5 Perfume      750
# 1     Dior Sauvage Cologne      900
# 2     Gucci Leather Wallet     1400
# 3        Hermès Silk Scarf     2500
# 4    Louis Vuitton Handbag    12000
# 5   Montblanc Fountain Pen     1500
# 6        Omega Speedmaster     6500
# 7         Rolex Submariner    20000
# 8  Tiffany Engagement Ring    15000
#
# Total Revenue per Day:
#          Date  Revenue
# 0  2025-08-01    22250
# 1  2025-08-02    19400
# 2  2025-08-03    18900
